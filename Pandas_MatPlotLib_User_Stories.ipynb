# %% [markdown]
# ## Visualizing Data with Pandas and MatPlotLib

# %% [markdown]
# ### As a Data Analyst, I want to set up the proper imports so I have access to the Pandas and MatPlotLib libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### As a Data Analyst, I want to import and store the `ufo_sightings.csv` file in a variable

# %%
df = pd.read_csv("ufo_sightings.csv")
df
# Out:
#            #         Date_Time                  City State/Province Country  \
# 0          0  10/10/1949 20:30            San Marcos             TX      US
# 1          1  10/10/1949 21:00          Lackland Afb             TX     NaN
# 2          2  10/10/1955 17:00  Chester (Uk/England)            NaN      GB
# 3          3  10/10/1956 21:00                  Edna             TX      US
# 4          4  10/10/1960 20:00               Kaneohe             HI      US
# ...      ...               ...                   ...            ...     ...
# 64678  65531   8/12/2011 23:15               Yonkers             NY      US
# 64679  65532   8/12/2011 23:27            Mandeville             LA      US
# 64680  65533   8/12/2012 00:00                 Davis             CA      US
# 64681  65534   8/12/2012 00:00                Peoria             IL      US
# 64682  65535   8/12/2012 00:15                Barron             WI      US
#
#        UFO_Shape  Length_of_Encounter Described_Duration  \
# 0       cylinder               2700.0         45 minutes
# 1          light               7200.0            1-2 hrs
# 2         circle                 20.0         20 seconds
# 3         circle                 20.0           1/2 hour
# 4          light                900.0         15 minutes
# ...          ...                  ...                ...
# 64678      light               3600.0             1 hour
# 64679     sphere                 60.0           1 minute
# 64680    unknown                900.0            15 mins
# 64681     circle                 40.0         40 seconds
# 64682  formation                  5.0          5 seconds
#
#                                              Description Date_Documented  \
# 0      This event took place in early fall around 194...       4/27/2004
# 1      1949 Lackland AFB&#44 TX.  Lights racing acros...      12/16/2005
# 2      Green/Orange circular disc over Chester&#44 En...       1/21/2008
# 3      My older brother and twin sister were leaving ...       1/17/2004
# 4      AS a Marine 1st Lt. flying an FJ4B fighter/att...       1/22/2004
# ...                                                  ...             ...
# 64678  Blinking lights in the sky not moving then dis...       8/21/2011
# 64679  Silent orange/red illuminated jagged spherical...       8/21/2011
# 64680  Multi colored lights seen heading northeast ov...       8/19/2012
# 64681                          Orange orb over peoria il       8/19/2012
# 64682  Five witnesses (Including myself) were watchin...      10/30/2012
#
#         Latitude   Longitude
# 0      29.883056  -97.941111
# 1      29.384210  -98.581082
# 2      53.200000   -2.916667
# 3      28.978333  -96.645833
# 4      21.418056 -157.803611
# ...          ...         ...
# 64678  40.931111  -73.899167
# 64679  30.358056  -90.065556
# 64680  38.545000 -121.739444
# 64681  40.693611  -89.588889
# 64682  45.401389  -91.848889
#
# [64683 rows x 12 columns]

# %% [markdown]
# ### As a Data Analyst, I want to ensure my DataFrame is cleaned by removing any **null** values

# %%
non_null_df = df.dropna()
non_null_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 53562 entries, 0 to 64682
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   #                    53562 non-null  int64
#  1   Date_Time            53562 non-null  object
#  2   City                 53562 non-null  object
#  3   State/Province       53562 non-null  object
#  4   Country              53562 non-null  object
#  5   UFO_Shape            53562 non-null  object
#  6   Length_of_Encounter  53562 non-null  float64
#  7   Described_Duration   53562 non-null  object
#  8   Description          53562 non-null  object
#  9   Date_Documented      53562 non-null  object
#  10  Latitude             53562 non-null  float64
#  11  Longitude            53562 non-null  float64
# dtypes: float64(3), int64(1), object(8)
# memory usage: 5.3+ MB

# %% [markdown]
# ### As a Data Analyst, I want to filter my DataFrame to remove any information that is not related to my analysis
# * This will include **dropping** the **Described_Duration, Description, and Date_Documented** columns

# %%
filtered_df = non_null_df.drop(["Described_Duration","Description","Date_Documented"], axis=1)
filtered_df
# Out:
#            #         Date_Time        City State/Province Country  UFO_Shape  \
# 0          0  10/10/1949 20:30  San Marcos             TX      US   cylinder
# 3          3  10/10/1956 21:00        Edna             TX      US     circle
# 4          4  10/10/1960 20:00     Kaneohe             HI      US      light
# 5          5  10/10/1961 19:00     Bristol             TN      US     sphere
# 7          7  10/10/1965 23:45     Norwalk             CT      US       disk
# ...      ...               ...         ...            ...     ...        ...
# 64678  65531   8/12/2011 23:15     Yonkers             NY      US      light
# 64679  65532   8/12/2011 23:27  Mandeville             LA      US     sphere
# 64680  65533   8/12/2012 00:00       Davis             CA      US    unknown
# 64681  65534   8/12/2012 00:00      Peoria             IL      US     circle
# 64682  65535   8/12/2012 00:15      Barron             WI      US  formation
#
#        Length_of_Encounter   Latitude   Longitude
# 0                   2700.0  29.883056  -97.941111
# 3                     20.0  28.978333  -96.645833
# 4                    900.0  21.418056 -157.803611
# 5                    300.0  36.595000  -82.188889
# 7                   1200.0  41.117500  -73.408333
# ...                    ...        ...         ...
# 64678               3600.0  40.931111  -73.899167
# 64679                 60.0  30.358056  -90.065556
# 64680                900.0  38.545000 -121.739444
# 64681                 40.0  40.693611  -89.588889
# 64682                  5.0  45.401389  -91.848889
#
# [53562 rows x 9 columns]

# %% [markdown]
# ### As a Data Analyst, I want to convert the `Date_Time` column to utilize Pandas' DateTime data type

# %%
filtered_df['Date_Time'] = pd.to_datetime(filtered_df['Date_Time'])

filtered_df.head()
# Out:
#    #           Date_Time        City State/Province Country UFO_Shape  \
# 0  0 1949-10-10 20:30:00  San Marcos             TX      US  cylinder
# 3  3 1956-10-10 21:00:00        Edna             TX      US    circle
# 4  4 1960-10-10 20:00:00     Kaneohe             HI      US     light
# 5  5 1961-10-10 19:00:00     Bristol             TN      US    sphere
# 7  7 1965-10-10 23:45:00     Norwalk             CT      US      disk
#
#    Length_of_Encounter   Latitude   Longitude
# 0               2700.0  29.883056  -97.941111
# 3                 20.0  28.978333  -96.645833
# 4                900.0  21.418056 -157.803611
# 5                300.0  36.595000  -82.188889
# 7               1200.0  41.117500  -73.408333

# %% [markdown]
# ## Data Visualization with Matplotlib

# %% [markdown]
# ### As a Data Analyst, I want to visualize the **frequency of different UFO shapes**, to determine which UFO shapes are most commonly encountered
# * I will use a **Bar Graph** to visualize this data
# * I will include a label for the X and Y axis
# * I will include a name for my chart

# %%
frequency_shapes_count = filtered_df["UFO_Shape"].value_counts()
frequency_shapes_count.plot.bar()
plt.xlabel("Type of Shape", fontsize=18);
plt.ylabel("Frequency of Shape", fontsize=18);
plt.title("Frequency of Different UFO Shapes",fontsize=20);

# %% [markdown]
# ### As a Data Analyst, I want to visualize the **number of UFO encounters**, grouped by each decade, to see if there is a correlation between number of sightings and decade
# * I will use a **Bar Graph** to visualize this data
# * I will include a label for the X and Y axis
# * I will include a name for my chart

# %%
filtered_df["Year"] = filtered_df["Date_Time"].dt.year
filtered_df["10 Year Interval"]=(filtered_df["Year"] // 10)*10
filtered_df['10 Year Interval'].value_counts().sort_index().plot.bar();

plt.xlabel("Year by Decade", fontsize=18);
plt.ylabel("Number of UFO Encounters", fontsize=18);
plt.title("Frequency of Different UFO Shapes",fontsize=20);

# %% [markdown]
# ### As a Data Analyst, I want to create a **Line Graph** to visualize the **Frequency of UFO sightings, by hour of the day**
# * I will use a **Line Graph** to visualize this data
# * I will include a label for the X and Y axis
# * I will include a name for my chart

# %%
filtered_df["Hour"] = filtered_df["Date_Time"].dt.hour
filtered_df.groupby("Hour").size().plot.line();
plt.xlabel("Hour of Day", fontsize=18);
plt.ylabel("Number of UFO Sightings", fontsize=18);
plt.title("Frequency of UFO Sightings by Hour of Day",fontsize=20);

# %% [markdown]
# ### As a Data Analyst, I want to answer all questions in the following Markdown block to provide a **clear and detailed analysis of my UFO sighting findings**

# %% [markdown]
# 1. Which UFO shape is the most frequently reported?
#     * Light is the most frequently reported shape.
#
# 2. Which shape is least frequently reported?
#     * Cross is the least frequently reported but Cone is a close second. Perhaps a different chart or a more detailed breakdown would show the exact difference.
#
# 3. Based on your analysis, what times of the day have the highest number of UFO sightings?
#     * The time of day with the highest number of UFO sightings would be at night around 8pm.
#
# 4. Are there other factors that may account for this pattern in the data?
#     * I would say yes.  If the most frequently reported shape is Light and the most common time for a sighting is 8pm, then they are probably being seen due to it being dark outside.
#
# 5. Do you see any surprising trends in the breakdown by decade? Do you have any theories or ideas that may explain these patterns?
#     * Definitely a lot of sightings in the 2000.  Could potentially be attributed to the rise in satelites.
#
# 6. Based on your data analysis, what recommendation would you give to individuals interested in encountering a UFO?
#     * For example, what time would be best to look, what UFO shapes should they expect to see, etc.
#     * I would recommend for someone interested in seeing a UFO, there best opportunity would be to go outside around 8pm and examine lights that appear.

# %% [markdown]
# ### **Bonus:** As a Data Analyst, I want to visualize the frequency of **different UFO shape sightings for Virginia, Wisconsin, and Tennessee**, to see if there is any variation of UFO shape frequency between states
# * I will use a **Grouped Bar Graph** to visualize this data
# * I will include a label for the X and Y axis
# * I will include a name for my chart
